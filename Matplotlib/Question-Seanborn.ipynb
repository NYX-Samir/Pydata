# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\evilk\Downloads\archive\supermarket_sales - Sheet1.csv')

# %% [markdown]
# ### sns.set_style()

# %%
sns.set_style("darkgrid")
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### histoplot vs Kdeplot

# %%
sns.set_style("darkgrid")
sns.histplot(df,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
tips=pd.read_csv(r"C:\Users\evilk\Downloads\archive\tips.csv")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("white")
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style("dark")
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style("whitegrid")
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style("darkgrid")
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style("ticks")
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,palette="coolwarm",hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(x=tips['total_bill'],y=tips['day'])

# %%
iris=sns.load_dataset('iris')
sns.pairplot(iris,hue='species',palette="magma",diag_kind='kde')
plt.show()

# %%
sns.boxplot(x="species",y="petal_length",data=iris,palette="coolwarm")
plt.show()
# Out:
# C:\Users\evilk\AppData\Local\Temp\ipykernel_3792\995519035.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species",y="petal_length",data=iris,palette="coolwarm")
