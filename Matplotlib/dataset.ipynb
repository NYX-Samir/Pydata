# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(1,10,100)
y=np.sin(x)
z=np.cos(x)

# %% [markdown]
# ### Sin graph

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Cos graph

# %%
plt.plot(x,z)
plt.show()
